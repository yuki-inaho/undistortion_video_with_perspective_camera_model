# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt

import cv2
from scripts.image import show_image_from_ndarray

# %%
import cv2
from pathlib import Path

SCRIPT_DIR = str(Path().parent)
image = cv2.imread(f"{SCRIPT_DIR}/data/001_fisheye.png")

show_image_from_ndarray(image)

# %%
from scripts.undistortion import Undistortion
undist = Undistortion(f"{SCRIPT_DIR}/config/cam0_fisheye.yml", use_fisheye_model=True)
print(f"K:\n{undist.K}\nD:\n{undist.D}\nsize:{undist.image_size}")
# Out:
# K:
# [[1.05435844e+03 0.00000000e+00 9.72838748e+02]
#  [0.00000000e+00 1.05909355e+03 5.20230638e+02]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
# D:
# [-0.01472341 -0.01088834  0.02443234 -0.01465887]
# size:(1920, 1080)

# %%
image_undistorted = undist.correction(image)
show_image_from_ndarray(image_undistorted)
