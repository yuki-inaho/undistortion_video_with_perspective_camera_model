# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt

import cv2
from scripts.image import show_image_from_ndarray

# %%
import cv2
from pathlib import Path

SCRIPT_DIR = str(Path().parent)
image = cv2.imread(f"{SCRIPT_DIR}/data/001.png")

show_image_from_ndarray(image)

# %%
from scripts.undistortion import Undistortion
undist = Undistortion(f"{SCRIPT_DIR}/config/cam0.yml")
print(f"K:\n{undist.K}\nD:\n{undist.D}\nsize:{undist.image_size}")
# Out:
# K:
# [[458.654   0.    367.215]
#  [  0.    457.296 248.375]
#  [  0.      0.      1.   ]]
# D:
# [-2.83408110e-01  7.39590700e-02  1.93590000e-04  1.76187114e-05
#   0.00000000e+00]
# size:(752, 480)

# %%
image_undistorted = undist.correction(image)
show_image_from_ndarray(image_undistorted)
